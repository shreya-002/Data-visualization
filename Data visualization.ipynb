# %% [markdown]
# # Data Exploration and Cleaning
# Data exploration is the first step of data analysis used to explore and visualize data to uncover insights from the start or identify areas or patterns to dig into more. Using interactive dashboards and point-and-click data exploration, users can better understand the bigger picture and get to insights faster.

# %%
# First of all we will analyse the data

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import HTML, display
import seaborn as sns

# %%
data= pd.read_csv("Airbnb Dataset 19.csv")   #Read the data
data_1 = pd.read_csv("HRDataset_v14.csv")

# %%
data.head()          # Display first 5 rows
data_1.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID
# 0       Adinolfi, Wilson  K  10026          0                0         1  \
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...
# 0            1       5            4                       0   62506  ...  \
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore
# ...

# %%
data.head()
# Out:
#      id                                              name  host_id
# 0  2539                Clean & quiet apt home by the park     2787  \
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude
# 0         John            Brooklyn    Kensington  40.64749  -73.97237  \
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review
# ...

# %%
data.shape     # Checking dimensions
# Out:
# (249, 16)

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
data.describe()
# Out:
#                  id       host_id    latitude   longitude       price
# count    249.000000  2.490000e+02  249.000000  249.000000  249.000000  \
# mean   31376.771084  1.499884e+05   40.730257  -73.964044  143.971888
# std    18101.018309  4.010393e+05    0.049660    0.029685   91.442975
# min     2539.000000  2.787000e+03   40.631880  -74.080880   35.000000
# 25%    15711.000000  5.014800e+04   40.688430  -73.984980   85.000000
# 50%    28321.000000  9.779700e+04   40.721620  -73.964280  125.000000
# 75%    46911.000000  1.936370e+05   40.761930  -73.948220  175.000000
# max    62430.000000  6.197784e+06   40.867540  -73.765970  800.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month
# count      249.000000         249.000000         242.000000  \
# mean         8.718876         103.445783           1.091653
# std         20.398680         100.337887           1.000168
# min          1.000000           0.000000           0.010000
# ...

# %%
data.isnull().sum()      # Checking null values
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       7
# reviews_per_month                 7
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# Checking number of neighbourhood_groups
data['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        124
# Brooklyn         111
# Queens            11
# Bronx              2
# Staten Island      1
# Name: count, dtype: int64

# %%
print("Neighbourhood Groups:", data['neighbourhood_group'].unique().tolist())
print("Neighbourhood:", data['neighbourhood'].unique().tolist())
print("Room Types:", data['room_type'].unique().tolist())
# Out:
# Neighbourhood Groups: ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']
# Neighbourhood: ['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem', 'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen", 'Upper West Side', 'Chinatown', 'South Slope', 'West Village', 'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights', 'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side', 'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay', 'SoHo', 'Upper East Side', 'Prospect Heights', 'Washington Heights', 'Woodside', 'Brooklyn Heights', 'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill', 'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George', 'Highbridge', 'Financial District', 'Ridgewood', 'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo', 'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island', 'Greenwich Village', 'Little Italy', 'East Flatbush']
# ...

# %%
# Ploting Neighbourhood_group
labels = ['Brooklyn', 'Bronx', 'Queens', 'Manhattan', 'Staten Island']
values = [111, 2, 11, 124, 1]
plt.pie(values, labels = labels, autopct = '%.1f%%')
plt.show()

# %%
labels = ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']
values = [111, 124, 11, 1, 2]
positions= [0,1,2,3,4]
plt.bar(positions, values, width=0.5)
plt.xticks(positions, labels)
plt.title('Share of neighbourhood')
plt.show()

# %%
# Checking price of airbnb in neighbourhood_group
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(data= data, x = data['neighbourhood_group'], y = data['price'])
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
data['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg                 26
# Harlem                       22
# East Village                 20
# Bedford-Stuyvesant           17
# Hell's Kitchen               12
# Clinton Hill                  9
# Upper West Side               9
# Fort Greene                   8
# West Village                  8
# Lower East Side               8
# Upper East Side               8
# South Slope                   7
# Chelsea                       7
# Greenpoint                    7
# East Harlem                   7
# Prospect Heights              7
# Park Slope                    6
# Bushwick                      5
# Chinatown                     3
# Midtown                       3
# Ridgewood                     3
# Washington Heights            3
# Middle Village                2
# Cobble Hill                   2
# Gowanus                       2
# Carroll Gardens               2
# SoHo                          2
# Kips Bay                      2
# ...

# %%
sns.set(rc={'figure.figsize':(60,15)})
sns.histplot(data['neighbourhood'])
# Out:
# <Axes: xlabel='neighbourhood', ylabel='Count'>

# %%
# Analysing room_type in airbnb
data['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    134
# Private room       113
# Shared room          2
# Name: count, dtype: int64

# %%
labels = ['Entire home/apt', 'Private room', 'Shared room']
values = [134, 113, 2]
explode= [ 0.05, 0, 0]
colors = ['g', 'r', 'b']
plt.figure(figsize=(5,5))
plt.pie(values, labels = labels, autopct = '%.1f%%', explode= explode, colors= colors)
plt.show()

# %%
# Analysing number of reviews in naighbourhood group
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(data= data, x = data['neighbourhood_group'], y = data['number_of_reviews'])
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='number_of_reviews'>

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.scatterplot(data= data, x = data['price'], y = data['number_of_reviews'])
# Out:
# <Axes: xlabel='price', ylabel='number_of_reviews'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.boxplot(data= data, x = data['neighbourhood_group'], y = data['availability_365'])
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='availability_365'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(data= data, x = data['room_type'], y = data['latitude'])
# Out:
# <Axes: xlabel='room_type', ylabel='latitude'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(data= data, x = data['room_type'], y = data['longitude'])
# Out:
# <Axes: xlabel='room_type', ylabel='longitude'>

# %%
# Park the analysis of airbnb here and now starts the analysis of HR dept.

# %%
data_1.shape         # Checking dimensions
# Out:
# (311, 36)

# %%
data_1.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
data_1.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
# As we can see there are many null values in column: Dateof Termination so we will drop it.

# %%
data_1['Department'].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
#Ploting pie chart for analysing employees in departments
labels = ['Production', 'Executive Office', 'IT/IS', 'Sales', 'Software Engineering', 'Admin Offices', ]
values = [209, 1, 50, 31, 11, 9]

plt.pie(values, labels = labels, autopct = '%.1f%%')
plt.show()

# %%
data_1['Sex'].value_counts()
# Out:
# Sex
# F     176
# M     135
# Name: count, dtype: int64

# %%
#Shows number of male and female employees
sns.histplot(data_1['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
#Analysis of department w.r.t salary 
sns.set(rc={'figure.figsize':(10,6)})
sns.barplot(data= data_1, x = data_1['Department'], y = data_1['Salary'])
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %%
# Checking gender of employees w.r.t. Department
sns.set(rc={'figure.figsize':(10,5)})
sns.violinplot(data= data_1, x = data_1['Department'], y = data_1['GenderID'])
# Out:
# <Axes: xlabel='Department', ylabel='GenderID'>

# %%
sns.set(rc={'figure.figsize':(9,5)})
sns.barplot(data= data_1, x = data_1['PerformanceScore'], y = data_1['Salary'])
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='Salary'>

# %%
data_1['EmpSatisfaction'].value_counts()
# Out:
# EmpSatisfaction
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: count, dtype: int64

# %%
sns.histplot(data_1['EmpSatisfaction'])
# Out:
# <Axes: xlabel='EmpSatisfaction', ylabel='Count'>

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.boxplot(data= data_1, x = data_1['Department'], y = data_1['SpecialProjectsCount'])
# Out:
# <Axes: xlabel='Department', ylabel='SpecialProjectsCount'>

# %%
sns.barplot(data= data_1, x = data_1['PerformanceScore'], y = data_1['EngagementSurvey'])
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='EngagementSurvey'>

# %%
data_1['ManagerName'].value_counts()
# Out:
# ManagerName
# Michael Albert        22
# Kissy Sullivan        22
# Elijiah Gray          22
# Kelley Spirea         22
# Brannon Miller        22
# Ketsia Liebig         21
# David Stanley         21
# Amy Dunn              21
# Webster Butler        21
# Janet King            19
# Simon Roup            17
# Peter Monroe          14
# John Smith            14
# Lynn Daneault         13
# Alex Sweetwater        9
# Brian Champaigne       8
# Brandon R. LeBlanc     7
# Jennifer Zamora        7
# Eric Dougall           4
# Debra Houlihan         3
# Board of Directors     2
# Name: count, dtype: int64

# %%
data_1['CitizenDesc'].value_counts()
# Out:
# CitizenDesc
# US Citizen             295
# Eligible NonCitizen     12
# Non-Citizen              4
# Name: count, dtype: int64

# %%
sns.histplot(data_1['CitizenDesc'])
# Out:
# <Axes: xlabel='CitizenDesc', ylabel='Count'>

# %%
# Wrap up
